# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\VARUN\\Desktop\\summer internship 2023\\datasets\\TidyData.csv")

# %%
print(df)
print(df.isnull().sum())
X = df.drop('Subject', axis=1)
X = X.drop('Activity', axis=1)
Y = df['Activity']
# Out:
#        Time domain:Bodyacceleration,mean valueon X axis  \
# 0                                              0.301648
# 1                                              0.343359
# 2                                              0.269674
# 3                                              0.268194
# 4                                              0.314191
# ...                                                 ...
# 10294                                          0.262239
# 10295                                          0.289112
# 10296                                          0.275739
# 10297                                          0.249621
# 10298                                          0.280580
#
#        Time domain:Bodyacceleration,mean valueon Y axis  \
# 0                                             -0.026884
# 1                                             -0.003426
# 2                                              0.010907
# 3                                             -0.012730
# 4                                             -0.008696
# ...                                                 ...
# 10294                                         -0.024959
# 10295                                         -0.014917
# 10296                                         -0.020032
# 10297                                         -0.018658
# 10298                                         -0.020204
#
#        Time domain:Bodyacceleration,mean valueon Z axis  \
# 0                                             -0.095796
# 1                                             -0.101545
# 2                                             -0.074949
# 3                                             -0.093653
# 4                                             -0.124561
# ...                                                 ...
# 10294                                         -0.084025
# 10295                                         -0.113559
# 10296                                         -0.102993
# 10297                                         -0.101252
# 10298                                         -0.102516
#
#        Time domain:Bodyacceleration,standard deviration valueon X axis  \
# 0                                              -0.380124
# 1                                              -0.201154
# 2                                              -0.336640
# 3                                              -0.383698
# 4                                              -0.355878
# ...                                                  ...
# 10294                                          -0.994454
# 10295                                          -0.982301
# 10296                                          -0.987218
# 10297                                          -0.982960
# 10298                                          -0.963065
#
#        Time domain:Bodyacceleration,standard deviration valueon Y axis  \
# 0                                              -0.191329
# 1                                               0.133154
# 2                                               0.146250
# 3                                              -0.203897
# 4                                              -0.165799
# ...                                                  ...
# 10294                                          -0.988798
# 10295                                          -0.979036
# 10296                                          -0.971719
# 10297                                          -0.991975
# 10298                                          -0.967258
#
#        Time domain:Bodyacceleration,standard deviration valueon Z axis  \
# 0                                               0.340558
# 1                                              -0.318171
# 2                                              -0.445571
# 3                                               0.148000
# 4                                               0.406729
# ...                                                  ...
# 10294                                          -0.985198
# 10295                                          -0.983547
# 10296                                          -0.951981
# 10297                                          -0.989093
# 10298                                          -0.982854
#
#        Time domain:Gravityacceleration,mean valueon X axis  \
# 0                                               0.902057
# 1                                               0.965457
# 2                                               0.959625
# 3                                               0.944190
# 4                                               0.892303
# ...                                                  ...
# 10294                                          -0.207293
# 10295                                          -0.702285
# 10296                                          -0.206182
# 10297                                          -0.263099
# 10298                                          -0.486826
#
#        Time domain:Gravityacceleration,mean valueon Y axis  \
# 0                                              -0.136611
# 1                                              -0.145033
# 2                                              -0.213868
# 3                                              -0.158757
# 4                                              -0.146982
# ...                                                  ...
# 10294                                           0.782115
# 10295                                           0.791761
# 10296                                           0.784270
# 10297                                           0.746230
# 10298                                           0.652758
#
#        Time domain:Gravityacceleration,mean valueon Z axis  \
# 0                                              -0.342825
# 1                                               0.028511
# 2                                               0.050544
# 3                                              -0.142527
# 4                                              -0.341419
# ...                                                  ...
# 10294                                           0.604451
# 10295                                           0.622483
# 10296                                           0.601610
# 10297                                           0.664450
# 10298                                           0.767055
#
#        Time domain:Gravityacceleration,standard deviration valueon X axis  \
# 0                                              -0.953011
# 1                                              -0.983711
# 2                                              -0.964750
# 3                                              -0.981235
# 4                                              -0.979758
# ...                                                  ...
# 10294                                          -0.983152
# 10295                                          -0.985844
# 10296                                          -0.986137
# 10297                                          -0.968676
# 10298                                          -0.977746
#
#        ...  \
# 0      ...
# 1      ...
# 2      ...
# 3      ...
# 4      ...
# ...    ...
# 10294  ...
# 10295  ...
# 10296  ...
# 10297  ...
# 10298  ...
#
#        Frequency domain:BodyBodyacceleration jerkmagnitude,standard deviration value  \
# 0                                              -0.068456
# 1                                              -0.230874
# 2                                              -0.138967
# 3                                              -0.072783
# 4                                              -0.056169
# ...                                                  ...
# 10294                                          -0.997309
# 10295                                          -0.965703
# 10296                                          -0.993303
# 10297                                          -0.995322
# 10298                                          -0.977210
#
#        Frequency domain:BodyBodyacceleration jerkmagnitude,meanFreq()  \
# 0                                               0.035432
# 1                                              -0.002726
# 2                                               0.024061
# 3                                               0.050816
# 4                                               0.156003
# ...                                                  ...
# 10294                                           0.481417
# 10295                                          -0.447513
# 10296                                           0.277147
# 10297                                           0.408803
# 10298                                           0.182653
#
#        Frequency domain:BodyBodyangular velocity jerkmagnitude,mean value  \
# 0                                              -0.355595
# 1                                              -0.414197
# 2                                              -0.149070
# 3                                               0.201820
# 4                                              -0.254988
# ...                                                  ...
# 10294                                          -0.994029
# 10295                                          -0.976198
# 10296                                          -0.991738
# 10297                                          -0.980392
# 10298                                          -0.943102
#
#        Frequency domain:BodyBodyangular velocity jerkmagnitude,standard deviration value  \
# 0                                              -0.473787
# 1                                              -0.589240
# 2                                              -0.331205
# 3                                              -0.191690
# 4                                              -0.394423
# ...                                                  ...
# 10294                                          -0.983957
# 10295                                          -0.976421
# 10296                                          -0.979171
# 10297                                          -0.983200
# 10298                                          -0.918656
#
#        Frequency domain:BodyBodyangular velocity jerkmagnitude,meanFreq()  \
# 0                                               0.188302
# 1                                               0.367610
# 2                                               0.268515
# 3                                               0.457120
# 4                                               0.093124
# ...                                                  ...
# 10294                                          -0.233253
# 10295                                          -0.102306
# 10296                                          -0.370457
# 10297                                           0.207933
# 10298                                          -0.139644
#
#        Frequency domain:BodyBodyangular velocity jerkmagnitude,mean value.1  \
# 0                                              -0.293505
# 1                                              -0.508549
# 2                                              -0.235415
# 3                                               0.061488
# 4                                              -0.294463
# ...                                                  ...
# 10294                                          -0.998465
# 10295                                          -0.982868
# 10296                                          -0.997933
# 10297                                          -0.987615
# 10298                                          -0.984295
#
#        Frequency domain:BodyBodyangular velocity jerkmagnitude,standard deviration value.1  \
# 0                                              -0.268786
# 1                                              -0.381967
# 2                                              -0.157936
# 3                                               0.149172
# 4                                              -0.255808
# ...                                                  ...
# 10294                                          -0.997925
# 10295                                          -0.978720
# 10296                                          -0.997180
# 10297                                          -0.986530
# 10298                                          -0.987118
#
#        Frequency domain:BodyBodyangular velocity jerkmagnitude,meanFreq().1  \
# 0                                              -0.112304
# 1                                               0.200104
# 2                                               0.214963
# 3                                               0.293295
# 4                                              -0.151243
# ...                                                  ...
# 10294                                           0.380901
# 10295                                           0.052193
# 10296                                           0.250381
# 10297                                           0.141138
# 10298                                           0.286563
#
#        Subject  Activity
# 0            7   WALKING
# 1            5   WALKING
# 2            6   WALKING
# 3           23   WALKING
# 4            7   WALKING
# ...        ...       ...
# 10294       17    LAYING
# 10295       20    LAYING
# 10296       17    LAYING
# 10297       24    LAYING
# 10298       12    LAYING
#
# [10299 rows x 81 columns]
# Time domain:Bodyacceleration,mean valueon X axis                                       0
# Time domain:Bodyacceleration,mean valueon Y axis                                       0
# Time domain:Bodyacceleration,mean valueon Z axis                                       0
# Time domain:Bodyacceleration,standard deviration valueon X axis                        0
# Time domain:Bodyacceleration,standard deviration valueon Y axis                        0
#                                                                                       ..
# Frequency domain:BodyBodyangular velocity jerkmagnitude,mean value.1                   0
# Frequency domain:BodyBodyangular velocity jerkmagnitude,standard deviration value.1    0
# Frequency domain:BodyBodyangular velocity jerkmagnitude,meanFreq().1                   0
# Subject                                                                                0
# Activity                                                                               0
# Length: 81, dtype: int64

# %%
print(X)
print(Y)
# Out:
#        Time domain:Bodyacceleration,mean valueon X axis  \
# 0                                              0.301648
# 1                                              0.343359
# 2                                              0.269674
# 3                                              0.268194
# 4                                              0.314191
# ...                                                 ...
# 10294                                          0.262239
# 10295                                          0.289112
# 10296                                          0.275739
# 10297                                          0.249621
# 10298                                          0.280580
#
#        Time domain:Bodyacceleration,mean valueon Y axis  \
# 0                                             -0.026884
# 1                                             -0.003426
# 2                                              0.010907
# 3                                             -0.012730
# 4                                             -0.008696
# ...                                                 ...
# 10294                                         -0.024959
# 10295                                         -0.014917
# 10296                                         -0.020032
# 10297                                         -0.018658
# 10298                                         -0.020204
#
#        Time domain:Bodyacceleration,mean valueon Z axis  \
# 0                                             -0.095796
# 1                                             -0.101545
# 2                                             -0.074949
# 3                                             -0.093653
# 4                                             -0.124561
# ...                                                 ...
# 10294                                         -0.084025
# 10295                                         -0.113559
# 10296                                         -0.102993
# 10297                                         -0.101252
# 10298                                         -0.102516
#
#        Time domain:Bodyacceleration,standard deviration valueon X axis  \
# 0                                              -0.380124
# 1                                              -0.201154
# 2                                              -0.336640
# 3                                              -0.383698
# 4                                              -0.355878
# ...                                                  ...
# 10294                                          -0.994454
# 10295                                          -0.982301
# 10296                                          -0.987218
# 10297                                          -0.982960
# 10298                                          -0.963065
#
#        Time domain:Bodyacceleration,standard deviration valueon Y axis  \
# 0                                              -0.191329
# 1                                               0.133154
# 2                                               0.146250
# 3                                              -0.203897
# 4                                              -0.165799
# ...                                                  ...
# 10294                                          -0.988798
# 10295                                          -0.979036
# 10296                                          -0.971719
# 10297                                          -0.991975
# 10298                                          -0.967258
#
#        Time domain:Bodyacceleration,standard deviration valueon Z axis  \
# 0                                               0.340558
# 1                                              -0.318171
# 2                                              -0.445571
# 3                                               0.148000
# 4                                               0.406729
# ...                                                  ...
# 10294                                          -0.985198
# 10295                                          -0.983547
# 10296                                          -0.951981
# 10297                                          -0.989093
# 10298                                          -0.982854
#
#        Time domain:Gravityacceleration,mean valueon X axis  \
# 0                                               0.902057
# 1                                               0.965457
# 2                                               0.959625
# 3                                               0.944190
# 4                                               0.892303
# ...                                                  ...
# 10294                                          -0.207293
# 10295                                          -0.702285
# 10296                                          -0.206182
# 10297                                          -0.263099
# 10298                                          -0.486826
#
#        Time domain:Gravityacceleration,mean valueon Y axis  \
# 0                                              -0.136611
# 1                                              -0.145033
# 2                                              -0.213868
# 3                                              -0.158757
# 4                                              -0.146982
# ...                                                  ...
# 10294                                           0.782115
# 10295                                           0.791761
# 10296                                           0.784270
# 10297                                           0.746230
# 10298                                           0.652758
#
#        Time domain:Gravityacceleration,mean valueon Z axis  \
# 0                                              -0.342825
# 1                                               0.028511
# 2                                               0.050544
# 3                                              -0.142527
# 4                                              -0.341419
# ...                                                  ...
# 10294                                           0.604451
# 10295                                           0.622483
# 10296                                           0.601610
# 10297                                           0.664450
# 10298                                           0.767055
#
#        Time domain:Gravityacceleration,standard deviration valueon X axis  \
# 0                                              -0.953011
# 1                                              -0.983711
# 2                                              -0.964750
# 3                                              -0.981235
# 4                                              -0.979758
# ...                                                  ...
# 10294                                          -0.983152
# 10295                                          -0.985844
# 10296                                          -0.986137
# 10297                                          -0.968676
# 10298                                          -0.977746
#
#        ...  Frequency domain:Bodyaccelerationmagnitude,meanFreq()  \
# 0      ...                                           0.199334
# 1      ...                                           0.210435
# 2      ...                                           0.246291
# 3      ...                                           0.288638
# 4      ...                                           0.221946
# ...    ...                                                ...
# 10294  ...                                          -0.111535
# 10295  ...                                           0.081651
# 10296  ...                                          -0.102043
# 10297  ...                                           0.095331
# 10298  ...                                           0.341044
#
#        Frequency domain:BodyBodyacceleration jerkmagnitude,mean value  \
# 0                                              -0.108088
# 1                                              -0.162536
# 2                                              -0.095774
# 3                                              -0.075290
# 4                                              -0.081013
# ...                                                  ...
# 10294                                          -0.997903
# 10295                                          -0.978042
# 10296                                          -0.995566
# 10297                                          -0.994827
# 10298                                          -0.971919
#
#        Frequency domain:BodyBodyacceleration jerkmagnitude,standard deviration value  \
# 0                                              -0.068456
# 1                                              -0.230874
# 2                                              -0.138967
# 3                                              -0.072783
# 4                                              -0.056169
# ...                                                  ...
# 10294                                          -0.997309
# 10295                                          -0.965703
# 10296                                          -0.993303
# 10297                                          -0.995322
# 10298                                          -0.977210
#
#        Frequency domain:BodyBodyacceleration jerkmagnitude,meanFreq()  \
# 0                                               0.035432
# 1                                              -0.002726
# 2                                               0.024061
# 3                                               0.050816
# 4                                               0.156003
# ...                                                  ...
# 10294                                           0.481417
# 10295                                          -0.447513
# 10296                                           0.277147
# 10297                                           0.408803
# 10298                                           0.182653
#
#        Frequency domain:BodyBodyangular velocity jerkmagnitude,mean value  \
# 0                                              -0.355595
# 1                                              -0.414197
# 2                                              -0.149070
# 3                                               0.201820
# 4                                              -0.254988
# ...                                                  ...
# 10294                                          -0.994029
# 10295                                          -0.976198
# 10296                                          -0.991738
# 10297                                          -0.980392
# 10298                                          -0.943102
#
#        Frequency domain:BodyBodyangular velocity jerkmagnitude,standard deviration value  \
# 0                                              -0.473787
# 1                                              -0.589240
# 2                                              -0.331205
# 3                                              -0.191690
# 4                                              -0.394423
# ...                                                  ...
# 10294                                          -0.983957
# 10295                                          -0.976421
# 10296                                          -0.979171
# 10297                                          -0.983200
# 10298                                          -0.918656
#
#        Frequency domain:BodyBodyangular velocity jerkmagnitude,meanFreq()  \
# 0                                               0.188302
# 1                                               0.367610
# 2                                               0.268515
# 3                                               0.457120
# 4                                               0.093124
# ...                                                  ...
# 10294                                          -0.233253
# 10295                                          -0.102306
# 10296                                          -0.370457
# 10297                                           0.207933
# 10298                                          -0.139644
#
#        Frequency domain:BodyBodyangular velocity jerkmagnitude,mean value.1  \
# 0                                              -0.293505
# 1                                              -0.508549
# 2                                              -0.235415
# 3                                               0.061488
# 4                                              -0.294463
# ...                                                  ...
# 10294                                          -0.998465
# 10295                                          -0.982868
# 10296                                          -0.997933
# 10297                                          -0.987615
# 10298                                          -0.984295
#
#        Frequency domain:BodyBodyangular velocity jerkmagnitude,standard deviration value.1  \
# 0                                              -0.268786
# 1                                              -0.381967
# 2                                              -0.157936
# 3                                               0.149172
# 4                                              -0.255808
# ...                                                  ...
# 10294                                          -0.997925
# 10295                                          -0.978720
# 10296                                          -0.997180
# 10297                                          -0.986530
# 10298                                          -0.987118
#
#        Frequency domain:BodyBodyangular velocity jerkmagnitude,meanFreq().1
# 0                                              -0.112304
# 1                                               0.200104
# 2                                               0.214963
# 3                                               0.293295
# 4                                              -0.151243
# ...                                                  ...
# 10294                                           0.380901
# 10295                                           0.052193
# 10296                                           0.250381
# 10297                                           0.141138
# 10298                                           0.286563
#
# [10299 rows x 79 columns]
# 0        WALKING
# 1        WALKING
# 2        WALKING
# 3        WALKING
# 4        WALKING
#           ...
# 10294     LAYING
# 10295     LAYING
# 10296     LAYING
# 10297     LAYING
# 10298     LAYING
# Name: Activity, Length: 10299, dtype: object

# %%
from collections import Counter
print(Counter(Y))
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=0)
X, Y = ros.fit_resample(X, Y)
print(Counter(Y))
# Out:
# Counter({'LAYING': 1944, 'STANDING': 1906, 'SITTING': 1777, 'WALKING': 1722, 'WALKING_UPSTAIRS': 1544, 'WALKING_DOWNSTAIRS': 1406})
# Counter({'WALKING': 1944, 'WALKING_UPSTAIRS': 1944, 'WALKING_DOWNSTAIRS': 1944, 'SITTING': 1944, 'STANDING': 1944, 'LAYING': 1944})

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
out = ['Time domain:Bodyacceleration,standard deviration valueon Z axis', 'Time domain:Gravityacceleration,mean valueon X axis',
       'Time domain:Gravityacceleration,mean valueon Y axis', 'Time domain:Gravityacceleration,mean valueon Z axis',
       'Time domain:Gravityacceleration,standard deviration valueon X axis',
       'Time domain:Gravityacceleration,standard deviration valueon Y axis',
       'Time domain:Gravityacceleration,standard deviration valueon Z axis',
       'Time domain:Bodyacceleration jerk,mean valueon X axis','Time domain:Bodyacceleration jerk,mean valueon Y axis',
       'Time domain:Bodyacceleration jerk,mean valueon Z axis']

# %%
for i in out:
    sns.boxplot(df[i])
    plt.show()
    print(X[i])
    Q1 = X[i].quantile(0.25)
    Q3 = X[i].quantile(0.75)
    IQR = Q3 - Q1
    print(IQR)
    upper = Q3 + 1.5 * IQR
    lower = Q1 - 1.5 * IQR
    print(upper)
    print(lower)
    out1 = X[X[i] < lower].values
    out2 = X[X[i] > upper].values
    X[i].replace(out1, lower, inplace=True)
    X[i].replace(out2, upper, inplace=True)
    sns.boxplot(X[i])
    plt.show()
# Out:
# 0        0.340558
# 1       -0.318171
# 2       -0.445571
# 3        0.148000
# 4        0.406729
#            ...
# 11659   -0.201699
# 11660   -0.386759
# 11661    0.057691
# 11662   -0.096218
# 11663   -0.349772
# Name: Time domain:Bodyacceleration,standard deviration valueon Z axis, Length: 11664, dtype: float64
# 0.7236041999999999
# 0.8322530299999998
# -2.0621637699999997
# 0        0.902057
# 1        0.965457
# 2        0.959625
# 3        0.944190
# 4        0.892303
#            ...
# 11659    0.909864
# 11660    0.859535
# 11661    0.929234
# 11662    0.948817
# 11663    0.852847
# Name: Time domain:Gravityacceleration,mean valueon X axis, Length: 11664, dtype: float64
# 0.12200269249999995
# 1.13688256625
# 0.6488717962500001
# 0       -0.136611
# 1       -0.145033
# 2       -0.213868
# 3       -0.158757
# 4       -0.146982
#            ...
# 11659   -0.318390
# 11660   -0.368495
# 11661   -0.207046
# 11662    0.152556
# 11663   -0.325718
# Name: Time domain:Gravityacceleration,mean valueon Y axis, Length: 11664, dtype: float64
# 0.333213467
# 0.58566349
# -0.747190378
# 0       -0.342825
# 1        0.028511
# 2        0.050544
# 3       -0.142527
# 4       -0.341419
#            ...
# 11659   -0.010389
# 11660   -0.185016
# 11661    0.087810
# 11662    0.050972
# 11663   -0.288222
# Name: Time domain:Gravityacceleration,mean valueon Z axis, Length: 11664, dtype: float64
# 0.309143025
# 0.6447175025
# -0.5918545975
# 0       -0.953011
# 1       -0.983711
# 2       -0.964750
# 3       -0.981235
# 4       -0.979758
#            ...
# 11659   -0.976217
# 11660   -0.958090
# 11661   -0.958182
# 11662   -0.971549
# 11663   -0.896257
# Name: Time domain:Gravityacceleration,standard deviration valueon X axis, Length: 11664, dtype: float64
# 0.035063480000000036
# -0.90651951
# -1.04677343
# 0       -0.936814
# 1       -0.953134
# 2       -0.939434
# 3       -0.972791
# 4       -0.961486
#            ...
# 11659   -0.961395
# 11660   -0.927011
# 11661   -0.894819
# 11662   -0.974425
# 11663   -0.968210
# Name: Time domain:Gravityacceleration,standard deviration valueon Y axis, Length: 11664, dtype: float64
# 0.04725288500000002
# -0.8720051225
# -1.0610166625000002
# 0       -0.921072
# 1       -0.989647
# 2       -0.945923
# 3       -0.966038
# 4       -0.940852
#            ...
# 11659   -0.938861
# 11660   -0.922622
# 11661   -0.864836
# 11662   -0.670951
# 11663   -0.801055
# Name: Time domain:Gravityacceleration,standard deviration valueon Z axis, Length: 11664, dtype: float64
# 0.06033499750000004
# -0.83428713625
# -1.0756271262500001
# 0        0.150531
# 1       -0.135136
# 2        0.126174
# 3       -0.035810
# 4       -0.225618
#            ...
# 11659    0.114634
# 11660    0.595097
# 11661    0.175580
# 11662    0.393516
# 11663    0.284342
# Name: Time domain:Bodyacceleration jerk,mean valueon X axis, Length: 11664, dtype: float64
# 0.04601816549999999
# 0.17110959324999997
# -0.012963068749999994
# 0       -0.239070
# 1       -0.063686
# 2        0.208253
# 3       -0.013649
# 4       -0.069864
#            ...
# 11659   -0.143203
# 11660   -0.114109
# 11661    0.005468
# 11662   -0.045782
# 11663   -0.117608
# Name: Time domain:Bodyacceleration jerk,mean valueon Y axis, Length: 11664, dtype: float64
# 0.0681228005
# 0.141876223
# -0.130614979
# 0       -0.153305
# 1       -0.263072
# 2        0.077321
# 3        0.251057
# 4       -0.093682
#            ...
# 11659    0.106430
# 11660   -0.081695
# 11661   -0.099703
# 11662    0.135197
# 11663    0.054862
# Name: Time domain:Bodyacceleration jerk,mean valueon Z axis, Length: 11664, dtype: float64
# 0.06871942249999999
# 0.13325456049999998
# -0.14162312949999997

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
rfc = RandomForestClassifier()

# %%
X_train,X_test,Y_train,Y_test =  train_test_split(X,Y,random_state=0,test_size=0.3)
rfc.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
Y_pred = rfc.predict(X_test)
print(accuracy_score(Y_test,Y_pred)*100)
# Out:
# 97.62857142857143
